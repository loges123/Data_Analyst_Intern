# %%
pip install seaborn

# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e4112a71-70fe-4f71-be3a-ae33888afd3a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4112a71-70fe-4f71-be3a-ae33888afd3a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
covid = pd.read_csv('corona.csv')

# %%
covid.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week
# 0                    5.04                35526
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          7 non-null      object
#  1   Confirmed               7 non-null      int64
#  2   Deaths                  7 non-null      int64
#  3   Recovered               7 non-null      int64
#  4   Active                  7 non-null      int64
#  5   New cases               7 non-null      int64
#  6   New deaths              7 non-null      int64
#  7   New recovered           7 non-null      int64
#  8   Deaths / 100 Cases      7 non-null      float64
#  9   Recovered / 100 Cases   7 non-null      float64
#  10  Deaths / 100 Recovered  7 non-null      float64
#  11  Confirmed last week     7 non-null      int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 800.0+ bytes

# %%
sns.lineplot(x='Deaths',y='Country/Region',data=covid)
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
sns.histplot(x='Deaths',y='Country/Region',data=covid)
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
sns.boxplot(x='Deaths',y='Country/Region',data=covid)
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
sns.scatterplot(x='Deaths',y='Country/Region',data=covid)
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>
