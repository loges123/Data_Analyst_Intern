# %%
import requests

# %%
import bs4

# %%
from bs4 import BeautifulSoup

# %%
url='https://www.thehindu.com/news/national/tamil-nadu/'

# %%
ws = requests.get(url)

# %%
BeautifulSoup(ws.text, 'html')
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml"><head><link href="https://www.thehindu.com/news/national/tamil-nadu/feeder/default.rss" rel="alternate" type="application/rss+xml"/><title>
# 	Tamil Nadu Latest News: Today’s Events &amp; Political Developments - The Hindu
# ...
